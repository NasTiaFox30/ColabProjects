# %% [markdown]
# <a href="https://colab.research.google.com/github/NasTiaFox30/ColabProjects/blob/master/Calculator_BMI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**⚖️🏋️ Kalkulator BMI**

# %% [markdown]
# Proste funkcje: obliczanie BMI
# Zacznijmy od funkcji liczącej wskaźnik masy ciała, czyli Body Mass Index (BMI).
#
# Wzór na obliczanie BMI: waga w kilogramach podzielona przez kwadrat wzrostu w metrach

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Jak widzisz, formuła przyjmuje dwie wartości:
#
# wagę (pierwotnie w kilogramach)
# wzrost (pierwotnie w metrach)
# Napisz funkcję bmi, która będzie przyjmować dwa argumenty.
#
# Napisz program, który pobiera od użytkownika wagę w kilogramach oraz wzrost w metrach, następnie za pomocą funkcji bmi oblicza wskaźnik i informuje użytkownika czy użytkownik ma niedowagę, prawidłową wagę lub nadwagę.
#
# https://pl.wikipedia.org/wiki/Wska%C5%BAnik_masy_cia%C5%82a

# %%
# Kalkulator BMI
waga = input("Podaj wagę w kg - ")
wzrost = input("Podaj wzrost w m - ")

def obliczBMI(waga, wzrost):
  bmi = float(waga) / (float(wzrost)**2)
  wskaznik = round(bmi,2)
  print("Twój BMI = ",bmi)
  if (bmi < 16.0 ):
    print("wygłodzenie")
  elif (16 < bmi < 16.99 ):
    print("wychudzenie")
  elif (17.0 < bmi < 18.49 ):
    print("niedowaga")
  elif (18.5 < bmi < 24.99 ):
    print("pożądana masa ciała")
  elif (25.0 < bmi < 29.99 ):
    print("nadwaga")
  elif (30.0 < bmi < 34.99 ):
    print("otyłość I stopnia")
  elif (35.0 < bmi < 39.99 ):
    print("otyłość II stopnia (duża)")
  elif (bmi > 40.0 ):
    print("otyłość III stopnia (chorobliwa)")

obliczBMI(waga, wzrost)
# Out:
# Podaj wagę w kg - 56.7
# Podaj wzrost w m - 1.69
# Twój BMI =  19.852246069815486
# pożądana masa ciała
