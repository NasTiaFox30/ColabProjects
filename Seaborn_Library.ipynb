# %% [markdown]
# <a href="https://colab.research.google.com/github/NasTiaFox30/ColabProjects/blob/master/Seaborn_Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**📊📉📈 Seaborn Library**
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##**Zadania do samodzielnego wykonania**

# %% [markdown]
# **Zadanie 1**:
#
# Stwórz wykres słupkowy (bar plot) z użyciem danych z zestawu danych tips. Wykorzystaj kolumnę day jako oś X, a kolumnę total_bill jako wartości dla słupków.
#
# Rozwiązanie:

# %%
tips = sns.load_dataset('tips')
sns.barplot(x='day', y='total_bill', data=tips, estimator=sum)
plt.show()

# %% [markdown]
# **Zadanie 2**:
#
# Stwórz histogram (distplot) z użyciem danych z zestawu danych tips. Wykorzystaj kolumnę total_bill jako wartości do utworzenia histogramu.
#
# Rozwiązanie:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')

sns.distplot(tips['total_bill'], bins=10)
plt.show()
# Out:
# <ipython-input-4-b072e56fd812>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'], bins=10)

# %% [markdown]
# **Zadanie 3**:
#
# Stwórz heatmap (mapa ciepła) z użyciem danych z zestawu danych flights. Wykorzystaj kolumnę month jako oś X, a kolumnę year jako oś Y, a wartością w komórce niech będzie liczba pasażerów.
#
# Rozwiązanie:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

flights = sns.load_dataset('flights')
flights = flights.pivot(index='month',columns='year', values='passengers')

sns.heatmap(flights)
plt.show()

# %% [markdown]
# Zadanie 4:
#
# Stwórz wykres punktowy (scatter plot) z użyciem danych z zestawu danych tips. Wykorzystaj kolumnę total_bill jako oś X, a kolumnę tip jako oś Y. Dodaj dodatkowy wymiar koloru do wykresu, który odpowiada kolumnie sex.
#
# Rozwiązanie:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset('tips')

sns.scatterplot(x='total_bill', y='tip', hue='sex', data=tips)
plt.show()

# %% [markdown]
# **Zadanie 5**:
#
# Stwórz wykres liniowy (line plot) z użyciem danych z zestawu danych fmri. Wykorzystaj kolumnę timepoint jako oś X, a kolumnę signal jako oś Y. Dodaj dodatkowy wymiar koloru do wykresu, który odpowiada kolumnie region.
#
# Rozwiązanie:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fmri = sns.load_dataset('fmri')

sns.lineplot(x='timepoint', y='signal', hue='region', data=fmri)
plt.show()
